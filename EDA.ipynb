# %%
#importing basics libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_excel('/content/drive/MyDrive/Amazon_Products_100k_.xlsx')
df.head()
# Out:
#         ASIN                                              Title         Brand  \
# 0  B08373426                           Million clear and human.  AmazonBasics
# 1  B03391197                         Audience report have want.          Puma
# 2  B02847632  Myself century eye consider kid far rich posit...            HP
# 3  B02988741                    Must amount fast sort marriage.          Dell
# 4  B08201102        Hundred card recognize own by part exactly.         Apple
#
#     Price  Rating  Number_of_Reviews  Category          Availability  \
# 0  310.22     2.0               4993    Office  Limited Availability
# 1  116.27     3.8               3424   Grocery          Out of Stock
# 2  101.04     4.5               3964    Beauty          Out of Stock
# 3  161.02     4.8               4559  Clothing          Out of Stock
# 4  265.51     1.5               1608    Beauty              In Stock
#
#                                          Description  Shipping_Weight (g)
# 0  However provide conference care moment small h...                  214
# 1  Onto fire firm pretty image compare cold. Mark...                 4192
# 2  Open sport product even behavior situation mea...                 4261
# 3                         Several whole mouth those.                 2922
# 4  Real main customer each. Study tax federal los...                  304

# %%
df.tail()
# Out:
#             ASIN                                              Title    Brand  \
# 99995  B08667654  Training yeah reality management operation tough.   Adidas
# 99996  B02381747         Lead still story drop democratic talk and.  Samsung
# 99997  B07608689                               Treat resource rock.     Dell
# 99998  B04308137    Maybe begin real list control election subject.   Adidas
# 99999  B02619627                         None ago paper remain act.       LG
#
#         Price  Rating  Number_of_Reviews  Category          Availability  \
# 99995  176.24     3.7               2337     Books  Limited Availability
# 99996  236.72     3.7               2704  Clothing              In Stock
# 99997  157.94     4.1               2839    Beauty              In Stock
# 99998  252.29     1.4               3193      Toys              In Stock
# 99999   86.69     3.5               3456   Grocery  Limited Availability
#
#                                              Description  Shipping_Weight (g)
# 99995  Box station two near owner. Shoulder himself m...                 4127
# 99996                         Air try size type machine.                  770
# 99997  Seven space court such option involve. Their w...                  193
# 99998  Mention matter their across kind play. Trainin...                 1343
# 99999  Once Congress method public. Thought large any...                 1510

# %%
## get the basics info about data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ASIN                 100000 non-null  object
#  1   Title                100000 non-null  object
#  2   Brand                100000 non-null  object
#  3   Price                100000 non-null  float64
#  4   Rating               100000 non-null  float64
#  5   Number_of_Reviews    100000 non-null  int64
#  6   Category             100000 non-null  object
#  7   Availability         100000 non-null  object
#  8   Description          100000 non-null  object
#  9   Shipping_Weight (g)  100000 non-null  int64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 7.6+ MB

# %%
df.describe()
# Out:
#                Price         Rating  Number_of_Reviews  Shipping_Weight (g)
# count  100000.000000  100000.000000      100000.000000        100000.000000
# mean      252.668772       2.999651        2506.902020          2552.451070
# std       142.943477       1.157164        1447.470546          1414.017525
# min         5.010000       1.000000           0.000000           100.000000
# 25%       128.670000       2.000000        1251.000000          1333.000000
# 50%       253.130000       3.000000        2507.000000          2554.000000
# 75%       376.312500       4.000000        3767.000000          3775.000000
# max       500.000000       5.000000        5000.000000          5000.000000

# %%
df.isnull().sum()
# Out:
# ASIN                   0
# Title                  0
# Brand                  0
# Price                  0
# Rating                 0
# Number_of_Reviews      0
# Category               0
# Availability           0
# Description            0
# Shipping_Weight (g)    0
# dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['Rating'], bins=20, kde=True, color='skyblue')
plt.title("Rating Distribution")
plt.show()

# %%
top_brands = df['Brand'].value_counts().head(10)
sns.barplot(x=top_brands.values, y=top_brands.index, palette='viridis')
plt.title("Top 10 Brands by Product Count")
plt.xlabel("Number of Products")
plt.ylabel("Brand")
plt.show()
# Out:
# /tmp/ipython-input-3193891476.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_brands.values, y=top_brands.index, palette='viridis')

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(data=df, x='Price', y='Rating', alpha=0.5)
plt.title("Price vs Rating")
plt.show()

# %%
cat_avg = df.groupby('Category')['Rating'].mean().sort_values()
cat_avg.plot(kind='barh', figsize=(8,6), color='coral')
plt.title("Average Rating by Category")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df['Price'])
plt.title("Price Outlier Detection")
plt.show()

plt.figure(figsize=(6,4))
sns.boxplot(x=df['Number_of_Reviews'])
plt.title("Reviews Outlier Detection")
plt.show()

# %%
sns.countplot(data=df, x='Availability', order=df['Availability'].value_counts().index)
plt.title("Product Availability")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Category', y='Price')
plt.xticks(rotation=90)
plt.title("Price Range per Category")
plt.show()
